# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 47.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 73.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 98.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="2t6xilh0yCbvKGshqtgh")
project = rf.workspace("redbean-xxypc").project("football-players-pl4fg")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import shutil

shutil.move('Football-Players-1/Football-Players-1/train',
            'Football-Players-1/train')
shutil.move('Football-Players-1/Football-Players-1/test',
            'Football-Players-1/test')
shutil.move('Football-Players-1/Football-Players-1/valid',
            'Football-Players-1/valid')
# Out:
# 'Football-Players-1/valid'

# %%
dataset.location
# Out:
# '/content/Football-Players-1'

# %%
# !yolo task=detect mode=train model=yolov5l6u.pt data={dataset.location}/data.yaml epochs=250 imgsz=640 batch=8 plots=True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.214 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import yaml
import os

# Load the data.yaml file
with open(f'{dataset.location}/data.yaml', 'r') as f:
    data = yaml.safe_load(f)

# Update the paths to reflect the new location of the directories
data['train'] = '../train/images'
data['val'] = '../valid/images'
data['test'] = '../test/images'

# Save the updated data.yaml file
with open(f'{dataset.location}/data.yaml', 'w') as f:
    yaml.dump(data, f)

print("Updated data.yaml:")
print(data)
# Out:
# Updated data.yaml:
# {'names': ['ball', 'player'], 'nc': 2, 'roboflow': {'license': 'CC BY 4.0', 'project': 'football-players-pl4fg', 'url': 'https://universe.roboflow.com/redbean-xxypc/football-players-pl4fg/dataset/1', 'version': 1, 'workspace': 'redbean-xxypc'}, 'test': '../test/images', 'train': '../train/images', 'val': '../valid/images'}

# %%
# !yolo task=detect mode=train model=yolov5l6u.pt data={dataset.location}/data.yaml epochs=250 imgsz=640 batch=8 plots=True
# Out:
# Ultralytics 8.3.214 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
